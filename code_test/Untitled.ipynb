# %%
import pandas as pd

# %%
df = pd.read_csv('data_modified/iot.csv')
df.shape
# Out:
# (53759, 27)

# %%
df
# Out:
#        unit_ID  cycles  time_to_deterioration  setting_1  setting_2  \
# 0            1       1                    148    34.9983     0.8400
# 1            1       2                    147    41.9982     0.8408
# 2            1       3                    146    24.9988     0.6218
# 3            1       4                    145    42.0077     0.8416
# 4            1       5                    144    25.0005     0.6203
# ...        ...     ...                    ...        ...        ...
# 53754      260     312                      4    20.0037     0.7000
# 53755      260     313                      3    10.0022     0.2510
# 53756      260     314                      2    25.0041     0.6200
# 53757      260     315                      1    25.0033     0.6220
# 53758      260     316                      0    35.0036     0.8400
#
#        setting_3      T2     T24      T30      T50  ...     phi      NRf  \
# 0          100.0  449.44  555.32  1358.61  1137.23  ...  183.06  2387.72
# ...

# %%
df[df['unit_ID']==1]
# Out:
#      unit_ID  cycles  time_to_deterioration  setting_1  setting_2  setting_3  \
# 0          1       1                    148    34.9983     0.8400      100.0
# 1          1       2                    147    41.9982     0.8408      100.0
# 2          1       3                    146    24.9988     0.6218       60.0
# 3          1       4                    145    42.0077     0.8416      100.0
# 4          1       5                    144    25.0005     0.6203       60.0
# ..       ...     ...                    ...        ...        ...        ...
# 144        1     145                      4    35.0007     0.8402      100.0
# 145        1     146                      3    10.0006     0.2516      100.0
# 146        1     147                      2    25.0005     0.6200       60.0
# 147        1     148                      1     0.0024     0.0013      100.0
# 148        1     149                      0    42.0017     0.8414      100.0
#
# ...

# %%
df[['unit_ID','cycles']].describe()
# Out:
#             unit_ID        cycles
# count  53759.000000  53759.000000
# mean     131.082981    109.154746
# std       74.463862     69.180569
# min        1.000000      1.000000
# 25%       68.000000     52.000000
# 50%      131.000000    104.000000
# 75%      195.000000    157.000000
# max      260.000000    378.000000

# %%
df_mod = pd.read_csv('data_modified/modeling_engine_partial.csv')
df_mod.shape
# Out:
# (2216, 51)

# %%
df_mod
# Out:
#       unit_ID  cycles  time_to_deterioration  setting_1-mean  setting_2-mean  \
# 0           1     120                     29       25.883372        0.628304
# 1           1     124                     25       23.723044        0.599132
# 2           1     125                     24       25.003032        0.622780
# 3           2     153                    116       28.482604        0.707784
# 4           2     173                     96       24.882896        0.615056
# ...       ...     ...                    ...             ...             ...
# 2211      260     130                    186       23.242544        0.537328
# 2212      260     156                    160       28.923252        0.657436
# 2213      260     169                    147       21.882824        0.498996
# 2214      260     172                    144       22.882808        0.531812
# 2215      260     186                    130       21.043268        0.518572
#
# ...

# %%
df = pd.read_csv('data_modified/iot.csv')
print(df.shape)
df.head()
# Out:
# (53759, 27)
#    unit_ID  cycles  time_to_deterioration  setting_1  setting_2  setting_3  \
# 0        1       1                    148    34.9983     0.8400      100.0
# 1        1       2                    147    41.9982     0.8408      100.0
# 2        1       3                    146    24.9988     0.6218       60.0
# 3        1       4                    145    42.0077     0.8416      100.0
# 4        1       5                    144    25.0005     0.6203       60.0
#
#        T2     T24      T30      T50  ...     phi      NRf      NRc      BPR  \
# 0  449.44  555.32  1358.61  1137.23  ...  183.06  2387.72  8048.56   9.3461
# 1  445.00  549.90  1353.22  1125.78  ...  130.42  2387.66  8072.30   9.3774
# 2  462.54  537.31  1256.76  1047.45  ...  164.22  2028.03  7864.87  10.8941
# 3  445.00  549.51  1354.03  1126.38  ...  130.72  2387.61  8068.66   9.3528
# 4  462.54  537.07  1257.71  1047.93  ...  164.31  2028.00  7861.23  10.8963
#
# ...

# %%
df1 = df[df["unit_ID"]==1]
df1
# Out:
#      unit_ID  cycles  time_to_deterioration  setting_1  setting_2  setting_3  \
# 0          1       1                    148    34.9983     0.8400      100.0
# 1          1       2                    147    41.9982     0.8408      100.0
# 2          1       3                    146    24.9988     0.6218       60.0
# 3          1       4                    145    42.0077     0.8416      100.0
# 4          1       5                    144    25.0005     0.6203       60.0
# ..       ...     ...                    ...        ...        ...        ...
# 144        1     145                      4    35.0007     0.8402      100.0
# 145        1     146                      3    10.0006     0.2516      100.0
# 146        1     147                      2    25.0005     0.6200       60.0
# 147        1     148                      1     0.0024     0.0013      100.0
# 148        1     149                      0    42.0017     0.8414      100.0
#
# ...

# %%
df1 = df1[(df1['cycles']>=95) & (df1['cycles']<=120)]
df1
# Out:
#      unit_ID  cycles  time_to_deterioration  setting_1  setting_2  setting_3  \
# 94         1      95                     54    35.0058     0.8403      100.0
# 95         1      96                     53    42.0062     0.8402      100.0
# 96         1      97                     52    42.0015     0.8413      100.0
# 97         1      98                     51     0.0025     0.0015      100.0
# 98         1      99                     50    10.0051     0.2502      100.0
# 99         1     100                     49    20.0027     0.7000      100.0
# 100        1     101                     48    42.0021     0.8400      100.0
# 101        1     102                     47    35.0063     0.8400      100.0
# 102        1     103                     46    20.0057     0.7010      100.0
# 103        1     104                     45    35.0078     0.8400      100.0
# 104        1     105                     44    20.0052     0.7000      100.0
# ...
